# %% [markdown]
# ## Implemented ACM validation

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import h5py
import glob as glob
import h5py
from gqp_mc import data as Data 
from gqp_mc import fitters as Fitters
from matplotlib import cm
from matplotlib import colors
from seaborn import cm as cmap

# %%
specs,meta = Data.Spectra(sim='lgal',noise = 'none', lib = 'bc03', sample = 'mini_mocha')
photo, _ = Data.Photometry(sim='lgal', noise= 'none', lib='bc03', sample='mini_mocha') 
input_mass = meta['logM_total'][:]

# %%
class convergence_plotter_single2():
    def __init__(self,walkers,num_run,data_dir,ID):
        self.num_walkers = walkers
        self.num_run = num_run
        self.data_dir = data_dir
        self.files = []
        self.ID = ID
        
    def opener(self, pr = False):
        f = [x for x in glob.glob(f'{self.data_dir}/*.{self.ID}.mcmc.hdf5')]  
        f.sort()
        if pr:
            print(f)
        files = []
        
        for i in f:
            file = h5py.File(i,'r')
            files.append(file)
        
        self.files = files
        return bool(len(f))
    
    def avg_perc_plot(self,ax, gal_idx, spec_photo,step=1000, flag = ''):
        data = self.files[0]['mcmc_chain'][...][:,0]
        perc_err = []
        
        y,up_perc,lo_perc = [], [], []
        length = len(data)
        inc = length//step
        x_axis = (np.arange(inc)+1)*step
        for n in range(inc):
            up = np.percentile(data[:step*(1+n)],84.1)
            lo = np.percentile(data[:step*(1+n)],15.9)
            med = np.median(data[:step*(1+n)])
            up_perc.append(up-med)
            lo_perc.append(med-lo)
            y.append(med)

        yerr = np.vstack((up_perc,lo_perc))    
        ax.set_xlabel('$N_{iteration}$')
        ax.set_ylabel('Median')
        ax.grid()
        ax.axhline(input_mass[gal_idx], lw = 1, c = 'r')
        ax.text(length,y[-1],f'{y[-1]}')
        ax.errorbar(x_axis,y,yerr=yerr,fmt = '.k', ecolor = 'gray', elinewidth=1,capsize=1)
    
    def get_output(self):
        data = self.files[0]['mcmc_chain'][...][:,0]
        med = np.median(data)
        return med 
    def get_err(self):
        data = self.files[0]['mcmc_chain'][...][:,0]
        med = np.median(data)
        up = np.percentile(data,84.1) - med
        lo = med - np.percentile(data, 15.9)
        return up, lo
    
    def get_length(self):
        data = self.files[0]['mcmc_chain'][...][:,0]
        return len(data)

# %%
path = os.environ.get('GQPMC_DIR') + 'mini_mocha/ispeculator/ACM/run_03/specphoto_0_96/'

# %%
compare = []
compare_up = []
compare_lo = []
comp_length = []
comp_length_dic = {}
for i in range(96):
    file = convergence_plotter_single2(40,100000,os.environ.get('GQPMC_DIR')+'mini_mocha/ispeculator/iSpeculator_validation/specphoto_0_96/',i)
    if file.opener():
        compare.append(file.get_output())
        up, lo = file.get_err()
        compare_up.append(up)
        compare_lo.append(lo)
        comp_length.append(file.get_length())
        comp_length_dic[i] = file.get_length()
    else:
        compare.append(-1)
        compare_up.append(0)
        compare_lo.append(0)
        comp_length.append(-1e8)

# %%
valid_set = []
for i in range(96):
    file = convergence_plotter_single2(40,1000000,path,i)
    if file.opener(pr = False):
        valid_set.append(file)
    else:
        valid_set.append('N/A')

# %%
print(len(valid_set))
print(valid_set)
# Out:
# 96
# [<__main__.convergence_plotter_single2 object at 0x1a5aace310>, <__main__.convergence_plotter_single2 object at 0x1ab9b3b590>, <__main__.convergence_plotter_single2 object at 0x1ab9b3b050>, <__main__.convergence_plotter_single2 object at 0x1a5a9febd0>, <__main__.convergence_plotter_single2 object at 0x1a5aacee10>, <__main__.convergence_plotter_single2 object at 0x1ab9b5f810>, <__main__.convergence_plotter_single2 object at 0x1ab9b5fc10>, <__main__.convergence_plotter_single2 object at 0x1ab9b5fc50>, <__main__.convergence_plotter_single2 object at 0x1ab9b5ffd0>, <__main__.convergence_plotter_single2 object at 0x1a5aace9d0>, <__main__.convergence_plotter_single2 object at 0x1ab9b5f890>, <__main__.convergence_plotter_single2 object at 0x1ab9b5ff50>, <__main__.convergence_plotter_single2 object at 0x1ab9b5fe90>, <__main__.convergence_plotter_single2 object at 0x1ab9b670d0>, <__main__.convergence_plotter_single2 object at 0x1ab9b674d0>, <__main__.convergence_plotter_single2 object at 0x1ab9b67450>, <__main__.convergence_plotter_single2 object at 0x1ab9b67190>, <__main__.convergence_plotter_single2 object at 0x1ab9b67350>, <__main__.convergence_plotter_single2 object at 0x1ab9b671d0>, 'N/A', <__main__.convergence_plotter_single2 object at 0x1ab9b672d0>, <__main__.convergence_plotter_single2 object at 0x1ab9b67210>, <__main__.convergence_plotter_single2 object at 0x1ab9b67890>, <__main__.convergence_plotter_single2 object at 0x1ab9b67610>, <__main__.convergence_plotter_single2 object at 0x1ab9b67550>, <__main__.convergence_plotter_single2 object at 0x1ab9b67790>, <__main__.convergence_plotter_single2 object at 0x1ab9b67650>, <__main__.convergence_plotter_single2 object at 0x1ab9b67090>, <__main__.convergence_plotter_single2 object at 0x1ab9b5dad0>, <__main__.convergence_plotter_single2 object at 0x1ab9b5dc50>, <__main__.convergence_plotter_single2 object at 0x1ab9b5ddd0>, <__main__.convergence_plotter_single2 object at 0x1ab9b5de50>, <__main__.convergence_plotter_single2 object at 0x1ab9b5ded0>, 'N/A', <__main__.convergence_plotter_single2 object at 0x1ab9b5dfd0>, <__main__.convergence_plotter_single2 object at 0x1ab9b5df50>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb050>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb0d0>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb190>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb210>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb290>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb310>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb390>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb410>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb490>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb510>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb590>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb610>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb690>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb710>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb790>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb810>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb890>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb910>, <__main__.convergence_plotter_single2 object at 0x1ab9fdb990>, 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A']

# %%
icefire = cmap.icefire

# %%
meds = []
ups = []
los = []
ACF_length = []
ACF_length_dic = {}
for i,s in enumerate(valid_set):
    if s != 'N/A':
#         fig, ax = plt.subplots(1,1)
#         s.avg_perc_plot(ax,i,'specphoto',10000)
        meds.append(s.get_output())
        up, lo = s.get_err()
        ups.append(up)
        los.append(lo)
        ACF_length.append(s.get_length())
        ACF_length_dic[i]=s.get_length()
    else:
        meds.append(-1)
        up,lo = (0,0)
        ups.append(up)
        los.append(lo)
        ACF_length.append(-1e8)

# %%
a = np.empty(len(ACF_length))
b = comp_length[:len(ACF_length)]
for i,acf_l in enumerate(ACF_length):
    if acf_l < 0:
        a[i] = 0
    else:
        if b[i] < 0:
            a[i] = 0
        else:
            a[i] = acf_l/b[i]

# %%
fig, axs = plt.subplots(2,3,figsize=(31,14), gridspec_kw={'height_ratios' : (10,4)})
xlim = axs[0,0].set_xlim(9,12)
axs[0,0].set_ylim(xlim)
axs[0,1].set_xlim(xlim)
axs[0,1].set_ylim(xlim)

for ax in axs:
    for x in ax:
        x.grid()


mask = (np.array(meds) != -1) & (np.array(compare[:len(meds)]) != -1)
# axs[0,0].errorbar(input_mass[:len(meds)],meds,yerr=(ups,los), elinewidth = 1, fmt = 'o', color = c,capsize = 2)
# axs[0,1].errorbar(input_mass[:len(meds)],compare[:len(meds)],yerr=(compare_up[:len(meds)], compare_lo[:len(meds)]), fmt = 'ok',elinewidth = 1, capsize = 2)
im1 = axs[0,0].scatter(input_mass[:len(meds)],meds, c = a, cmap = icefire)
im2 = axs[0,1].scatter(input_mass[:len(meds)],compare[:len(meds)],c = a, cmap = icefire)

axs[0,2].hist(a[a != 0], bins = np.linspace(0,8.0,17), histtype = 'step', color = 'maroon', density = True, lw = 1.5, zorder = 10)
axs[0,2].set_title('ACF chain length / GRD chain length', fontsize = 15)

axs[1,0].set_ylim(-0.45,0.45)
axs[1,1].set_ylim(-0.45,0.45)

axs[1,0].scatter(input_mass[:len(meds)],np.array(meds)-np.array(input_mass[:len(meds)]), c = 'k')
axs[1,1].scatter(input_mass[:len(meds)],np.array(compare[:len(meds)])-np.array(input_mass[:len(meds)]), c = 'k')
axs[1,2].hist(np.array(ACF_length)[mask], histtype = 'step', density = True, color = 'maroon', lw = 1.5, label = 'ACF')
axs[1,2].hist(np.array(comp_length)[:len(meds)][mask], histtype = 'step', density = True, color = 'k', lw = 1.5, label = 'GRD')
axs[1,2].legend(frameon = True, fontsize = 15)
axs[1,2].set_yticklabels(np.array([]))
axs[0,2].set_yticklabels(np.array([]))

cb1 = fig.colorbar(im1, ax = axs[0,0])
cb2 = fig.colorbar(im2, ax = axs[0,1])

cb1.set_label('Length Ratio', fontsize = 15)
cb2.set_label('Length Ratio', fontsize = 15)

axs[0,0].set_title('Autocorrelation Time Implementation\nwithout \'Safety Lever\'', fontsize = 15)
axs[0,1].set_title('Gelman-Rubin Diagnostic Implementation\nwith \'Safety Lever\'', fontsize = 15)

axs[0,0].set_xlabel('$\\theta$', fontsize = 15)
axs[0,0].set_ylabel('$\hat{\\theta}$', fontsize = 15)

axs[0,1].set_xlabel('$\\theta$', fontsize = 15)
axs[0,1].set_ylabel('$\hat{\\theta}$', fontsize = 15)

axs[0,2].set_xlabel('Length Ratio', fontsize = 15)
axs[0,2].set_ylabel('Density', fontsize = 15)

axs[1,0].axhline(0,c = 'r', lw = 1)
axs[1,1].axhline(0,c = 'r', lw = 1)

mask2 = np.array(meds) != -1
mask3 = np.array(compare) != -1

axs[1,0].axhline(np.mean(np.array(meds)[mask2] -np.array(input_mass[:len(meds)])[mask2]), c = 'b', lw = 1.5, label = 'Mean')
axs[1,1].axhline(np.mean(np.array(compare)[mask3]-np.array(input_mass[:len(compare)])[mask3]), c = 'b', lw = 1.5, label = 'Mean')
axs[1,0].legend(frameon = False, fontsize = 15)
axs[1,1].legend(frameon = False, fontsize = 15)

axs[0,0].plot([9,12],[9,12], c = 'r', lw = 1.5)
axs[0,1].plot([9,12],[9,12], c = 'r', lw = 1.5)

axs[1,2].set_ylabel('Density', fontsize = 15)
axs[1,1].set_ylabel('Residual', fontsize = 15)
axs[1,0].set_ylabel('Residual', fontsize = 15)

axs[1,2].set_xlabel('Chain Length', fontsize = 15)

fig.suptitle('ACF & GRD comparison - Spectrophotometry',  y= 0.97, fontsize = 20)
plt.show()

# %%
print(input_mass)
# Out:
# [9.747969802095955, 10.493215691743266, 10.742608960945535, 9.861245642460881, 10.076913176328167, 10.310913671568002, 10.461292015093738, 10.434245980846487, 9.675984821087692, 10.831515925259865, 10.119601503220357, 10.839954917990429, 10.712756000861702, 10.200127742891594, 10.335589575365953, 11.39353501569102, 10.361897259588021, 9.959802781646879, 11.254951380786741, 9.427278921839951, 9.621425535448061, 11.078545718015542, 9.654049975041108, 10.50670766301596, 9.640932383351053, 10.78529028863986, 10.300513820986756, 10.534171187989765, 11.176137199426998, 9.85332325410158, 10.936491469387038, 11.070486973977292, 11.125988722862537, 9.998664134759142, 10.121706545378244, 11.404651065819088, 10.27992370400917, 10.271595044486368, 10.757259459786201, 10.370261882092446, 10.78421128088577, 9.720359636854093, 11.638766397169567, 10.01307231453463, 9.771625511529237, 10.323232429255535, 11.152466479465579, 10.224520791939169, 10.49200551857217, 10.55879973126864, 10.333136791357733, 11.262358585883442, 10.304748888205095, 10.597870754087406, 10.577794536574144, 11.214752493561111, 10.322363148034414, 10.442747152520155, 9.686966712611218, 10.905348463758937, 10.474961327831263, 10.06905405602436, 10.893233467059101, 11.307558903723473, 9.4476278427236, 10.299648810286874, 9.927310075204288, 9.636914874031435, 10.276431974091087, 10.81623856145562, 10.262289414271313, 9.635903828226983, 11.102975602445461, 10.6573909446179, 11.182441629570759, 10.784673090542814, 11.16361003266612, 10.232184662562158, 10.4805956927708, 10.737170353363226, 11.346689415786223, 10.1021692623682, 9.960975914134913, 10.350407089791567, 10.983821057580492, 11.086383316340358, 10.382169694312818, 9.748386236470884, 11.178095643619695, 10.15407144620465, 10.201660714807435, 10.747215844866718, 10.182612436197733, 9.460046970405992, 11.366000997220533, 11.18563046913805, 9.667954460714313, 10.372858237711029, 10.573896420123397, 10.589762570617285]
